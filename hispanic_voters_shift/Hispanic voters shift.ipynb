# %%
import pandas as pd

pd.set_option('display.max_columns', None)  # or 1000
pd.set_option('display.max_rows', None)  # or 1000
pd.set_option('display.max_colwidth', None)  # or 199

# %%
population_by_county = pd.read_csv("hispanic_by_county/DECENNIALPL2020.P2_data_with_overlays_2021-12-12T053118.csv")

# %%
population_by_county.head()
# Out:
#            GEO_ID                     NAME    P2_001N  \
# 0              id     Geographic Area Name   !!Total:
# 1  0500000US01001  Autauga County, Alabama      58805
# 2  0500000US01003  Baldwin County, Alabama     231767
# 3  0500000US01005  Barbour County, Alabama      25223
# 4  0500000US01007     Bibb County, Alabama      22293
#
#                          P2_002N                             P2_003N  \
# 0   !!Total:!!Hispanic or Latino   !!Total:!!Not Hispanic or Latino:
# 1                           2117                               56688
# 2                          12686                              219081
# 3                           1510                               23713
# 4                            740                               21553
#
#                                              P2_004N  \
# 0   !!Total:!!Not Hispanic or Latino:!!Population...
# 1                                              54198
# 2                                             208713
# 3                                              23160
# 4                                              20953
#
#                                              P2_005N  \
# 0   !!Total:!!Not Hispanic or Latino:!!Population...
# 1                                              41582
# 2                                             186495
# 3                                              11086
# 4                                              16442
#
#                                              P2_006N  \
# 0   !!Total:!!Not Hispanic or Latino:!!Population...
# 1                                              11352
# 2                                              18001
# 3                                              11850
# 4                                               4390
#
#                                              P2_007N  \
# 0   !!Total:!!Not Hispanic or Latino:!!Population...
# 1                                                184
# 2                                               1291
# 3                                                 58
# 4                                                 39
#
#                                              P2_008N  ...  \
# 0   !!Total:!!Not Hispanic or Latino:!!Population...  ...
# 1                                                873  ...
# 2                                               2029  ...
# 3                                                103  ...
# 4                                                 26  ...
#
#                                              P2_064N  \
# 0   !!Total:!!Not Hispanic or Latino:!!Population...
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#                                              P2_065N  \
# 0   !!Total:!!Not Hispanic or Latino:!!Population...
# 1                                                  0
# 2                                                  0
# 3                                                  2
# 4                                                  0
#
#                                              P2_066N  \
# 0   !!Total:!!Not Hispanic or Latino:!!Population...
# 1                                                  0
# 2                                                  0
# 3                                                  2
# 4                                                  0
#
#                                              P2_067N  \
# 0   !!Total:!!Not Hispanic or Latino:!!Population...
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#                                              P2_068N  \
# 0   !!Total:!!Not Hispanic or Latino:!!Population...
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#                                              P2_069N  \
# 0   !!Total:!!Not Hispanic or Latino:!!Population...
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#                                              P2_070N  \
# 0   !!Total:!!Not Hispanic or Latino:!!Population...
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#                                              P2_071N  \
# 0   !!Total:!!Not Hispanic or Latino:!!Population...
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#                                              P2_072N  \
# 0   !!Total:!!Not Hispanic or Latino:!!Population...
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#                                              P2_073N
# 0   !!Total:!!Not Hispanic or Latino:!!Population...
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
# [5 rows x 75 columns]

# %%
population_by_county = population_by_county[["GEO_ID", "NAME", "P2_001N", "P2_002N"]][1:]

# %%
population_by_county.head()
# Out:
#            GEO_ID                     NAME P2_001N P2_002N
# 1  0500000US01001  Autauga County, Alabama   58805    2117
# 2  0500000US01003  Baldwin County, Alabama  231767   12686
# 3  0500000US01005  Barbour County, Alabama   25223    1510
# 4  0500000US01007     Bibb County, Alabama   22293     740
# 5  0500000US01009   Blount County, Alabama   59134    5771

# %%
def get_county(geo_id):
    try:
        return geo_id.split("US")[1]
    except:
        return "NA"

# %%
population_by_county['county'] = population_by_county.GEO_ID.apply(lambda geo_id: get_county(geo_id))

# %%
population_by_county.head()
# Out:
#            GEO_ID                     NAME P2_001N P2_002N county
# 1  0500000US01001  Autauga County, Alabama   58805    2117  01001
# 2  0500000US01003  Baldwin County, Alabama  231767   12686  01003
# 3  0500000US01005  Barbour County, Alabama   25223    1510  01005
# 4  0500000US01007     Bibb County, Alabama   22293     740  01007
# 5  0500000US01009   Blount County, Alabama   59134    5771  01009

# %%
population_by_county.to_csv('data/population_by_county.csv', index=False)

# %%
def get_election_result(year, county_id):
    url = "https://uselectionatlas.org/RESULTS/statesub.php?year={year}&fips={county_id}&f=0&off=0&elect=0".format(year=year, county_id=county_id)
    r = requests.get(url)
    results = pd.read_html(r.text)[1]
    last_col = len(results.columns)-1
    
    popular_vote_pop = "Unnamed: " + str(last_col-1)
    popular_vote_perc = "Unnamed: " + str(last_col)
    try:
        results.rename(columns={'PoliticalParty': 'party',
                            'PresidentialCandidate': 'candidate',
                            'Vice PresidentialCandidate': 'vp',
                           popular_vote_pop: 'popular_vote_pop',
                           popular_vote_perc: 'popular_vote_perc'}, inplace=True)
        results = results.loc[:, ["candidate", "party", "popular_vote_pop", "popular_vote_perc"]]

        if (results.loc[0, 'party'] == 'Democratic') {
            dem_candidate = [results.loc[0, 'candidate']], 
            dem_vote = [results.loc[0, 'popular_vote_pop']],
            demo_score = [results.loc[0, 'popular_vote_perc']]
            
            rep_candidate= [results.loc[1, 'candidate']], 
            rep_vote= [results.loc[1, 'popular_vote_pop']],
            rep_score= [results.loc[1, 'popular_vote_perc']]
        } else {
            dem_candidate = [results.loc[1, 'candidate']], 
            dem_vote = [results.loc[1, 'popular_vote_pop']],
            demo_score = [results.loc[1, 'popular_vote_perc']]
            
            rep_candidate= [results.loc[0, 'candidate']], 
            rep_vote= [results.loc[0, 'popular_vote_pop']],
            rep_score= [results.loc[0, 'popular_vote_perc']]
        }
        return {'year': [year],
                'county': [county_id],
                ,
                
               }
    except:
        return {'year': [year],
                'county': [county_id],
                'dem_candidate': ['NA'], 
                'dem_vote': ['NA'],
                'dem_score': ['NA'],
                'rep_candidate': ['NA'], 
                'rep_vote': ['NA'],
                'rep_score': ['NA']}

# %%
county_ids = population_by_county.county
election_results = pd.DataFrame()
for year in [2016, 2020]:
    for county_id in county_ids:
        print('%s - %s' % (year, county_id))
        res_in_county = get_election_result(year, county_id)
        
        election_results = pd.concat([election_results, pd.DataFrame(res_in_county)])

# %%
election_results = pd.read_csv("data/election_results.csv")

# %%
election_results.head()
# Out:
#    year  county    dem_candidate  dem_vote dem_score    rep_candidate  \
# 0  2016    1001  Donald J. Trump   18172.0    72.77%  Hillary Clinton
# 1  2016    1003  Donald J. Trump   72883.0    76.55%  Hillary Clinton
# 2  2016    1005  Donald J. Trump    5454.0    52.10%  Hillary Clinton
# 3  2016    1007  Donald J. Trump    6738.0    76.40%  Hillary Clinton
# 4  2016    1009  Donald J. Trump   22859.0    89.33%  Hillary Clinton
#
#    rep_vote rep_score
# 0    5936.0    23.77%
# 1   18458.0    19.39%
# 2    4871.0    46.53%
# 3    1874.0    21.25%
# 4    2156.0     8.43%

# %%
election_results.to_csv("data/election_results.csv", index=False)

# %%
election_results.loc[0, "year"]

# %%
def dem_results(df):
    def dem_result(data, col="candidate"):
        if (data == "Hillary Clinton") or (data == "Joseph R. Biden, Jr."):
            return df["dem_" + col] 
        else: 
            return df["rep_" + col] 
        
    def rep_result(df, col="candidate"):
        if (df.rep_candidate == "Donald J. Trump"): 
            return df["rep_" + col] 
        else:
            return df["dem_" + col]
    
    dem_candidate = df.apply(lambda df: dem_result(df, col="candidate"))
    dem_vote = df.apply(lambda df: dem_result(df, col="vote"))
    dem_score = df.apply(lambda df: dem_result(df, col="score"))
    
    rep_candidate = df.apply(lambda df: rep_result(df, col="candidate"))
    rep_vote = df.apply(lambda df: rep_result(df, col="vote"))
    rep_score = df.apply(lambda df: rep_result(df, col="score"))

    return pd.DataFrame({"year": df.year, "county": df.county,
                         "dem_candidate": dem_candidate, "dem_vote": dem_vote, "dem_score": dem_score,
                         "rep_candidate": rep_candidate, "rep_vote": rep_vote, "rep_score": rep_score})

# %%
dem_results(election_results.dem_candidate[1:10])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1968902/838725993.py in <module>
# ----> 1 dem_results(election_results.dem_candidate[1:10])
#
# /tmp/ipykernel_1968902/2026753497.py in dem_results(df)
#      12             return df["dem_" + col]
#      13
# ---> 14     dem_candidate = df.apply(lambda df: dem_result(df, col="candidate"))
#      15     dem_vote = df.apply(lambda df: dem_result(df, col="vote"))
#      16     dem_score = df.apply(lambda df: dem_result(df, col="score"))
#
# ~/cygraph/vizenv/lib/python3.8/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# ~/cygraph/vizenv/lib/python3.8/site-packages/pandas/core/apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# ~/cygraph/vizenv/lib/python3.8/site-packages/pandas/core/apply.py in apply_standard(self)
#    1096                 # List[Union[Callable[..., Any], str]]]]]"; expected
#    1097                 # "Callable[[Any], Any]"
# -> 1098                 mapped = lib.map_infer(
#    1099                     values,
#    1100                     f,  # type: ignore[arg-type]
#
# ~/cygraph/vizenv/lib/python3.8/site-packages/pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# /tmp/ipykernel_1968902/2026753497.py in <lambda>(df)
#      12             return df["dem_" + col]
#      13
# ---> 14     dem_candidate = df.apply(lambda df: dem_result(df, col="candidate"))
#      15     dem_vote = df.apply(lambda df: dem_result(df, col="vote"))
#      16     dem_score = df.apply(lambda df: dem_result(df, col="score"))
#
# /tmp/ipykernel_1968902/2026753497.py in dem_result(df, col)
#       1 def dem_results(df):
#       2     def dem_result(df, col="candidate"):
# ----> 3         if (df.dem_candidate == "Hillary Clinton") or (df.dem_candidate == "Joseph R. Biden, Jr."):
#       4             return df["dem_" + col]
#       5         else:
#
# AttributeError: 'str' object has no attribute 'dem_candidate'

# %%
dem_results()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1968902/2554448573.py in <module>
# ----> 1 dem_results(election_results[1:10])
#
# /tmp/ipykernel_1968902/2026753497.py in dem_results(df)
#      12             return df["dem_" + col]
#      13
# ---> 14     dem_candidate = df.apply(lambda df: dem_result(df, col="candidate"))
#      15     dem_vote = df.apply(lambda df: dem_result(df, col="vote"))
#      16     dem_score = df.apply(lambda df: dem_result(df, col="score"))
#
# ~/cygraph/vizenv/lib/python3.8/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8738             kwargs=kwargs,
#    8739         )
# -> 8740         return op.apply()
#    8741
#    8742     def applymap(
#
# ~/cygraph/vizenv/lib/python3.8/site-packages/pandas/core/apply.py in apply(self)
#     686             return self.apply_raw()
#     687
# --> 688         return self.apply_standard()
#     689
#     690     def agg(self):
#
# ~/cygraph/vizenv/lib/python3.8/site-packages/pandas/core/apply.py in apply_standard(self)
#     810
#     811     def apply_standard(self):
# --> 812         results, res_index = self.apply_series_generator()
#     813
#     814         # wrap results
#
# ~/cygraph/vizenv/lib/python3.8/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     826             for i, v in enumerate(series_gen):
#     827                 # ignore SettingWithCopy here in case the user mutates
# --> 828                 results[i] = self.f(v)
#     829                 if isinstance(results[i], ABCSeries):
#     830                     # If we have a view on v, we need to make a copy because
#
# /tmp/ipykernel_1968902/2026753497.py in <lambda>(df)
#      12             return df["dem_" + col]
#      13
# ---> 14     dem_candidate = df.apply(lambda df: dem_result(df, col="candidate"))
#      15     dem_vote = df.apply(lambda df: dem_result(df, col="vote"))
#      16     dem_score = df.apply(lambda df: dem_result(df, col="score"))
#
# /tmp/ipykernel_1968902/2026753497.py in dem_result(df, col)
#       1 def dem_results(df):
#       2     def dem_result(df, col="candidate"):
# ----> 3         if (df.dem_candidate == "Hillary Clinton") or (df.dem_candidate == "Joseph R. Biden, Jr."):
#       4             return df["dem_" + col]
#       5         else:
#
# ~/cygraph/vizenv/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'dem_candidate'

# %%
elections_results.dem_candidate.apply(lambda )

# %%
election_results.to_csv('data/election_results_na.csv', index=False)

# %%
election_results[election_results.county == "02070"]
# Out:
#    year county dem_candidate dem_vote dem_score rep_candidate rep_vote  \
# 0  2016  02070            NA       NA        NA            NA       NA
# 0  2020  02070            NA       NA        NA            NA       NA
#
#   rep_score
# 0        NA
# 0        NA

# %%
population_by_county.merge(election_results, by='county')
# Out:
#    a  b
# 0  1  3
# 1  2  4
# 0 -1  6
# 1  5  7

# %%
population_by_county[population_by_county.county == "02070"]
# Out:
#             GEO_ID                            NAME P2_001N P2_002N county
# 76  0500000US02070  Dillingham Census Area, Alaska    4857     146  02070

# %%
soup = BeautifulSoup(r.text)
#print(soup.prettify())
#print soup.find_all('tr')

table = soup.find("table", { "class" : "result" })

# %%
results_table = pd.read_html(str(table))[0]
last_col = len(results_table.columns)-1
    
popular_vote_pop = "Unnamed: " + str(last_col-1)
popular_vote_perc = "Unnamed: " + str(last_col)

# %%
len(results_table.columns)
# Out:
# 11

# %%
# Out:
# 4

# %%
from bs4 import BeautifulSoup
import requests

# %%
pd.DataFrame(res)
# Out:
#           dem_candidate  dem_vote dem_score    rep_candidate  rep_vote  \
# 0  Joseph R. Biden, Jr.   97297.0    56.31%  Donald J. Trump   73480.0
#
#   rep_score
# 0    42.53%

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1968902/2497667230.py in <module>
# ----> 1 pd.DataFrame(res)
#
# ~/cygraph/vizenv/lib/python3.8/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     612         elif isinstance(data, dict):
#     613             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 614             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     615         elif isinstance(data, ma.MaskedArray):
#     616             import numpy.ma.mrecords as mrecords
#
# ~/cygraph/vizenv/lib/python3.8/site-packages/pandas/core/internals/construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     462         # TODO: can we get rid of the dt64tz special case above?
#     463
# --> 464     return arrays_to_mgr(
#     465         arrays, data_names, index, columns, dtype=dtype, typ=typ, consolidate=copy
#     466     )
#
# ~/cygraph/vizenv/lib/python3.8/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity, typ, consolidate)
#     117         # figure out the index, if necessary
#     118         if index is None:
# --> 119             index = _extract_index(arrays)
#     120         else:
#     121             index = ensure_index(index)
#
# ~/cygraph/vizenv/lib/python3.8/site-packages/pandas/core/internals/construction.py in _extract_index(data)
#     623
#     624         if not indexes and not raw_lengths:
# --> 625             raise ValueError("If using all scalar values, you must pass an index")
#     626
#     627         if have_series:
#
# ValueError: If using all scalar values, you must pass an index

# %%
results#results.rename({'popular_vote_pop': 'Unnamed: 7', 'Unnamed: 9': 'popular_vote_perc'})
# Out:
#               candidate       party  popular_vote_pop popular_vote_perc
# 0       Donald J. Trump  Republican            5859.0            71.43%
# 1  Joseph R. Biden, Jr.  Democratic            2243.0            27.34%

# %%
results
# Out:
#               candidate       party  popular_vote_pop popular_vote_perc
# 0       Donald J. Trump  Republican            5859.0            71.43%
# 1  Joseph R. Biden, Jr.  Democratic            2243.0            27.34%
